# %% [markdown]
# <a href="https://colab.research.google.com/github/michaelfarayola7/Data-Science-ML-Projects/blob/main/Online_Book_Store_Web_Scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import lxml
import bs4

# %% [markdown]
# #Looping through the pages

# %%
pages = []
prices = []
ratings = []
title = []
urls = []

no_of_pages= 20 #number of pages to be selected


#looping through the required pages and selecting the pages accordingly
for i in range(1,no_of_pages+1): #to include the last page
    url=('http://books.toscrape.com/catalogue/page-{}.html'.format(i))




    pages.append(url) #adding all the content of the respective pages to our created page list

# %%
print('Number of Pages:', len(pages))
print(pages)
# Out:
# Number of Pages: 20
# ...

# %% [markdown]
# <br>
#
# **Getting the data from the particular page url and converting from object of type 'request to object of type beautiful soup, making it more readable**

# %%
for item in pages:
    page=requests.get(item)
    soup=bs4.BeautifulSoup(page.text,'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]--><!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:32" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %% [markdown]
# In an actual html tag, it includes indentations and nested tags that helps you to identify the actual relationship between tags and so forth. In order to get that identation and relationship here, we have to use what is called **prettify()**.
#
# **“prettify()”** is a built-in function provided by the Beautiful Soup module which gives the visual representation of the parsed URL Source code. i.e. it arranges all the tags in a parse-tree manner with better readability.

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:32" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %% [markdown]
# Finding all the titles

# %%
soup.select('h3')[0].text
# Out:
# 'Hide Away (Eve Duncan ...'

# %%
#print all the titles

for t in soup.findAll('h3'):
  print(t)
# Out:
# <h3><a href="hide-away-eve-duncan-20_620/index.html" title="Hide Away (Eve Duncan #20)">Hide Away (Eve Duncan ...</a></h3>
# <h3><a href="furiously-happy-a-funny-book-about-horrible-things_619/index.html" title="Furiously Happy: A Funny Book About Horrible Things">Furiously Happy: A Funny ...</a></h3>
# <h3><a href="everyday-italian-125-simple-and-delicious-recipes_618/index.html" title="Everyday Italian: 125 Simple and Delicious Recipes">Everyday Italian: 125 Simple ...</a></h3>
# <h3><a href="equal-is-unfair-americas-misguided-fight-against-income-inequality_617/index.html" title="Equal Is Unfair: America's Misguided Fight Against Income Inequality">Equal Is Unfair: America's ...</a></h3>
# <h3><a href="eleanor-park_616/index.html" title="Eleanor &amp; Park">Eleanor &amp; Park</a></h3>
# <h3><a href="dirty-dive-bar-1_615/index.html" title="Dirty (Dive Bar #1)">Dirty (Dive Bar #1)</a></h3>
# ...

# %%
#@title
#find all the title and add to our empty title list
for t in soup.select('h3'):
    titless=t.getText()
    print(titless)
# Out:
# Hide Away (Eve Duncan ...
# Furiously Happy: A Funny ...
# Everyday Italian: 125 Simple ...
# Equal Is Unfair: America's ...
# Eleanor & Park
# Dirty (Dive Bar #1)
# Can You Keep a ...
# Boar Island (Anna Pigeon ...
# A Paris Apartment
# A la Mode: 120 ...
# Troublemaker: Surviving Hollywood and ...
# The Widow
# The Sleep Revolution: Transforming ...
# The Improbability of Love
# The Art of Startup ...
# Take Me Home Tonight ...
# Sleeping Giants (Themis Files ...
# Setting the World on ...
# Playing with Fire
# Off the Hook (Fishing ...

# %%
#@title
#find all the title and add to our empty title list
for t in soup.findAll('h3'):
    titles=t.getText()
    title.append(titles)

# %%
title
# Out:
# ['Hide Away (Eve Duncan ...',
#  'Furiously Happy: A Funny ...',
#  'Everyday Italian: 125 Simple ...',
#  "Equal Is Unfair: America's ...",
#  'Eleanor & Park',
#  'Dirty (Dive Bar #1)',
#  'Can You Keep a ...',
#  'Boar Island (Anna Pigeon ...',
#  'A Paris Apartment',
#  'A la Mode: 120 ...',
#  'Troublemaker: Surviving Hollywood and ...',
#  'The Widow',
#  'The Sleep Revolution: Transforming ...',
#  'The Improbability of Love',
#  'The Art of Startup ...',
#  'Take Me Home Tonight ...',
#  'Sleeping Giants (Themis Files ...',
#  'Setting the World on ...',
#  'Playing with Fire',
#  'Off the Hook (Fishing ...']

# %% [markdown]
# ### Finding all the Prices

# %%
soup.find_all('p', class_ = 'price_color')
# Out:
# [<p class="price_color">Â£11.84</p>,
#  <p class="price_color">Â£41.46</p>,
#  <p class="price_color">Â£20.10</p>,
#  <p class="price_color">Â£56.86</p>,
#  <p class="price_color">Â£56.51</p>,
#  <p class="price_color">Â£40.83</p>,
#  <p class="price_color">Â£48.64</p>,
#  <p class="price_color">Â£59.48</p>,
#  <p class="price_color">Â£39.01</p>,
#  <p class="price_color">Â£38.77</p>,
#  <p class="price_color">Â£48.39</p>,
#  <p class="price_color">Â£27.26</p>,
#  <p class="price_color">Â£11.68</p>,
#  <p class="price_color">Â£59.45</p>,
#  <p class="price_color">Â£21.00</p>,
#  <p class="price_color">Â£53.98</p>,
#  <p class="price_color">Â£48.74</p>,
#  <p class="price_color">Â£21.15</p>,
#  <p class="price_color">Â£13.71</p>,
#  <p class="price_color">Â£47.67</p>]

# %%
#find all the prices

for p in soup.find_all('p', class_ = 'price_color'):
  price = p.getText()
  prices.append(price)

# %%
prices
# Out:
# ['Â£11.84',
#  'Â£41.46',
#  'Â£20.10',
#  'Â£56.86',
#  'Â£56.51',
#  'Â£40.83',
#  'Â£48.64',
#  'Â£59.48',
#  'Â£39.01',
#  'Â£38.77',
#  'Â£48.39',
#  'Â£27.26',
#  'Â£11.68',
#  'Â£59.45',
#  'Â£21.00',
#  'Â£53.98',
#  'Â£48.74',
#  'Â£21.15',
#  'Â£13.71',
#  'Â£47.67']

# %% [markdown]
# ### Finding all the ratings

# %%
soup.select('p', class_='star-rating')
# Out:
# [<p class="star-rating One">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="price_color">Â£11.84</p>,
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>,
#  <p class="star-rating Four">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="price_color">Â£41.46</p>,
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>,
#  <p class="star-rating Five">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="price_color">Â£20.10</p>,
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>,
#  <p class="star-rating One">
# ...

# %%
soup.findAll('p', class_='star-rating')
# Out:
# [<p class="star-rating One">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Four">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Five">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating One">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Five">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Four">
#  <i class="icon-star"></i>
# ...

# %%
#getting the ratings
for s in soup.find_all('p',class_='star-rating'):
    for k,v in s.attrs.items(): #to read about attr: https://www.attrs.org/en/stable/, k will contain the class(u can print(k) to see what is inside, V is going to contain a list like ['star-rating', 'Two'], we use v[1] to get the second item which is the actual ratings)
        star=v[1]
        ratings.append(star)
        print(star) #our star list now contains all of the star-ratings of the books
# Out:
# One
# Four
# Five
# One
# Five
# Four
# One
# Three
# Four
# One
# Two
# Two
# Four
# One
# Three
# Three
# One
# Two
# Three
# Three

# %%
s
# Out:
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>

# %%
s.attrs.items()
# Out:
# dict_items([('class', ['star-rating', 'Three'])])

# %%
k
# Out:
# 'class'

# %%
v
# Out:
# ['star-rating', 'Three']

# %% [markdown]
# Finding all the URL's of the images

# %%
divs = soup.find_all('div', class_ = 'image_container')

for thumbs in divs:
  tagss = thumbs.find('img', class_='thumbnail')

  links = 'http://books.toscrape.com' + str(tagss['src'])
  newlinks = links.replace('..','')
  urls.append(newlinks)

# %%
divs
# Out:
# [<div class="image_container">
#  <a href="hide-away-eve-duncan-20_620/index.html"><img alt="Hide Away (Eve Duncan #20)" class="thumbnail" src="../media/cache/57/07/5707c3d5d4fd44d943d51730ba7d429a.jpg"/></a>
#  </div>,
#  <div class="image_container">
#  <a href="furiously-happy-a-funny-book-about-horrible-things_619/index.html"><img alt="Furiously Happy: A Funny Book About Horrible Things" class="thumbnail" src="../media/cache/ab/2a/ab2ae4f02aa46271b4bfc77494039fc6.jpg"/></a>
#  </div>,
#  <div class="image_container">
#  <a href="everyday-italian-125-simple-and-delicious-recipes_618/index.html"><img alt="Everyday Italian: 125 Simple and Delicious Recipes" class="thumbnail" src="../media/cache/5a/64/5a6499d41ccaad4c4f7eeaa90e16345a.jpg"/></a>
#  </div>,
#  <div class="image_container">
# ...

# %%
print(tagss)
# Out:
# <img alt="Off the Hook (Fishing for Trouble #1)" class="thumbnail" src="../media/cache/1d/78/1d78fe226e1adb9cb591fa21f8a9bf68.jpg"/>

# %%
tagss['src']
# Out:
# '../media/cache/1d/78/1d78fe226e1adb9cb591fa21f8a9bf68.jpg'

# %%
type(tagss)
# Out:
# bs4.element.Tag

# %%
links
# Out:
# 'http://books.toscrape.com../media/cache/1d/78/1d78fe226e1adb9cb591fa21f8a9bf68.jpg'

# %%
newlinks
# Out:
# 'http://books.toscrape.com/media/cache/1d/78/1d78fe226e1adb9cb591fa21f8a9bf68.jpg'

# %%
urls
# Out:
# ['http://books.toscrape.com/media/cache/57/07/5707c3d5d4fd44d943d51730ba7d429a.jpg',
#  'http://books.toscrape.com/media/cache/ab/2a/ab2ae4f02aa46271b4bfc77494039fc6.jpg',
#  'http://books.toscrape.com/media/cache/5a/64/5a6499d41ccaad4c4f7eeaa90e16345a.jpg',
#  'http://books.toscrape.com/media/cache/00/11/001153d2a22d889837efac1703e10a5e.jpg',
#  'http://books.toscrape.com/media/cache/ed/d7/edd781d3c9d63a395f80f241445e88fa.jpg',
#  'http://books.toscrape.com/media/cache/ae/90/ae903f6f6d059954be4e85497dd76bf5.jpg',
#  'http://books.toscrape.com/media/cache/0b/2f/0b2f432cc27132f688fcdf29618521e0.jpg',
#  'http://books.toscrape.com/media/cache/d5/81/d58157866ea8f015a8e4c55b23b8c96f.jpg',
#  'http://books.toscrape.com/media/cache/16/57/16575316618bd7e922d5b0e0f87de2ca.jpg',
#  'http://books.toscrape.com/media/cache/98/19/9819ff3a8290dc6ab8797d00de5ec554.jpg',
#  'http://books.toscrape.com/media/cache/77/82/778285b3c87d6d5d98003aa0f2f65933.jpg',
# ...

# %% [markdown]
# **Data Processing on Scraped Data**
#
# We will create a **Pandas DataFrame** which will contain all the data we have scraped.
#
# First let's create a dictionary for all the data.

# %%
web_data = {'Title':title, 'Price':prices, 'Ratings':ratings, 'URL':urls}

# %%
#make sure all your arrays are of the same length
print(len(title))
print(len(prices))
print(len(ratings))
print(len(urls))
# Out:
# 20
# 20
# 20
# 20

# %%
import pandas as pd
df = pd.DataFrame(web_data)

# %%
df
# Out:
#                                         Title    Price Ratings  \
# 0                   Hide Away (Eve Duncan ...  Â£11.84     One
# 1                Furiously Happy: A Funny ...  Â£41.46    Four
# 2            Everyday Italian: 125 Simple ...  Â£20.10    Five
# 3              Equal Is Unfair: America's ...  Â£56.86     One
# 4                              Eleanor & Park  Â£56.51    Five
# 5                         Dirty (Dive Bar #1)  Â£40.83    Four
# 6                          Can You Keep a ...  Â£48.64     One
# 7                Boar Island (Anna Pigeon ...  Â£59.48   Three
# 8                           A Paris Apartment  Â£39.01    Four
# 9                          A la Mode: 120 ...  Â£38.77     One
# 10  Troublemaker: Surviving Hollywood and ...  Â£48.39     Two
# 11                                  The Widow  Â£27.26     Two
# 12     The Sleep Revolution: Transforming ...  Â£11.68    Four
# 13                  The Improbability of Love  Â£59.45     One
# ...

# %%
df.index += 1

# %%
df
# Out:
#                                         Title    Price Ratings  \
# 1                   Hide Away (Eve Duncan ...  Â£11.84     One
# 2                Furiously Happy: A Funny ...  Â£41.46    Four
# 3            Everyday Italian: 125 Simple ...  Â£20.10    Five
# 4              Equal Is Unfair: America's ...  Â£56.86     One
# 5                              Eleanor & Park  Â£56.51    Five
# 6                         Dirty (Dive Bar #1)  Â£40.83    Four
# 7                          Can You Keep a ...  Â£48.64     One
# 8                Boar Island (Anna Pigeon ...  Â£59.48   Three
# 9                           A Paris Apartment  Â£39.01    Four
# 10                         A la Mode: 120 ...  Â£38.77     One
# 11  Troublemaker: Surviving Hollywood and ...  Â£48.39     Two
# 12                                  The Widow  Â£27.26     Two
# 13     The Sleep Revolution: Transforming ...  Â£11.68    Four
# 14                  The Improbability of Love  Â£59.45     One
# ...

# %% [markdown]
# Taking away the currency

# %%
df['Price'] = df['Price'].str.replace('Â£','')

# %%
df
# Out:
#                                         Title  Price Ratings  \
# 1                   Hide Away (Eve Duncan ...  11.84     One
# 2                Furiously Happy: A Funny ...  41.46    Four
# 3            Everyday Italian: 125 Simple ...  20.10    Five
# 4              Equal Is Unfair: America's ...  56.86     One
# 5                              Eleanor & Park  56.51    Five
# 6                         Dirty (Dive Bar #1)  40.83    Four
# 7                          Can You Keep a ...  48.64     One
# 8                Boar Island (Anna Pigeon ...  59.48   Three
# 9                           A Paris Apartment  39.01    Four
# 10                         A la Mode: 120 ...  38.77     One
# 11  Troublemaker: Surviving Hollywood and ...  48.39     Two
# 12                                  The Widow  27.26     Two
# 13     The Sleep Revolution: Transforming ...  11.68    Four
# 14                  The Improbability of Love  59.45     One
# ...

# %% [markdown]
# We can sort the price to see the highest price

# %%
df.sort_values(by='Price', ascending=False, inplace = True)

# %% [markdown]
# Converting the ratings column to an integer

# %%
df['Ratings'] = df['Ratings'].replace({'One':1,'Two':2,'Three':3,'Four':4,'Five':5})

# %%
df
# Out:
#                                         Title  Price  Ratings  \
# 8                Boar Island (Anna Pigeon ...  59.48        3
# 14                  The Improbability of Love  59.45        1
# 4              Equal Is Unfair: America's ...  56.86        1
# 5                              Eleanor & Park  56.51        5
# 16                   Take Me Home Tonight ...  53.98        3
# 17          Sleeping Giants (Themis Files ...  48.74        1
# 7                          Can You Keep a ...  48.64        1
# 11  Troublemaker: Surviving Hollywood and ...  48.39        2
# 20                  Off the Hook (Fishing ...  47.67        3
# 2                Furiously Happy: A Funny ...  41.46        4
# 6                         Dirty (Dive Bar #1)  40.83        4
# 9                           A Paris Apartment  39.01        4
# 10                         A la Mode: 120 ...  38.77        1
# 12                                  The Widow  27.26        2
# ...

# %%
df.dtypes
# Out:
# Title      object
# Price      object
# Ratings     int64
# URL        object
# dtype: object

# %%
df['Price'] = df['Price'].astype(float)

# %%
df.dtypes
# Out:
# Title       object
# Price      float64
# Ratings      int64
# URL         object
# dtype: object

# %% [markdown]
# **Is there a correlation between the ratings and the price of the product**

# %%
df.corr()
# Out:
# <ipython-input-44-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             Price   Ratings
# Price    1.000000 -0.161115
# Ratings -0.161115  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
sns.heatmap(df.corr())
plt.show()
# Out:
# <ipython-input-45-afc2eec1cdc4>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
