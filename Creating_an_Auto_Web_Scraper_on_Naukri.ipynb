# %% [markdown]
# <a href="https://colab.research.google.com/github/michaelfarayola7/Data-Science-ML-Projects/blob/main/Creating_an_Auto_Web_Scraper_on_Naukri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Problem Statement**

# %% [markdown]
# Scrape all job postings by area from the links given in the file ‘link_by_areas.csv’. For every link, loop through all the job postings by page, collecting all the information for a given posting.
#
# Create an output CSV file with job title, company, experience, salary, location, description, tags associated, function area, posting date, scraping date.

# %% [markdown]
# # **Solution**

# %% [markdown]
# The task at hand is to build a Python Auto Scraper tool that will scrape data from Naukri job site and save the output as a CSV file which can be used for further analysis.
#
#
# In order to accomplish this task. I will be using ***Python*** to scrape the required data from the job search site-***Naukri***.

# %% [markdown]
# To begin with, the necessary libraries needs to be imported.
#
# **WebDriver**: drives a browser natively, as a user would, either locally or on a remote machine using the Selenium server, marks a leap forward in terms of browser automation.
#
# **Selenium WebDriver**: refers to both the language bindings and the implementations of the individual browser controlling code. This is commonly referred to as just WebDriver.
#
# **Beautiful Soup**: is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree.
#
# **Pandas**: is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language. Used for dataframe manupulations.

# %%
# Importing the libraries

from selenium import webdriver
import chromedriver_binary
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\users\micha\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: webencodings in c:\users\micha\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\micha\anaconda3\lib\site-packages (from html5lib) (1.16.0)

# %%
joblink = pd.read_csv('link_by_areas.csv')

# %%
joblink
# Out:
#                             type  \
# 0                Accounting Jobs
# 1           Interior Design Jobs
# 2                      Bank Jobs
# 3           Content Writing Jobs
# 4                Consultant Jobs
# 5               Engineering Jobs
# 6             Export Import Jobs
# 7              Merchandiser Jobs
# 8                  Security Jobs
# 9                        HR Jobs
# 10                    Hotel Jobs
# 11  Application Programming Jobs
# 12            Client Server Jobs
# 13                      DBA Jobs
# 14                Ecommerce Jobs
# 15                      ERP Jobs
# 16                     VLSI Jobs
# 17                Mainframe Jobs
# 18               Middleware Jobs
# 19                   Mobile Jobs
# 20    Network administrator Jobs
# 21                       IT Jobs
# 22                  Testing Jobs
# 23       System Programming Jobs
# 24                      EDP Jobs
# 25         Telecom Software Jobs
# 26                  Telecom Jobs
# 27                      BPO Jobs
# 28                    Legal Jobs
# 29                Marketing Jobs
# 30                Packaging Jobs
# 31                   Pharma Jobs
# 32              Maintenance Jobs
# 33                Logistics Jobs
# 34                    Sales Jobs
# 35                Secretary Jobs
# 36       Corporate Planning Jobs
# 37         Site Engineering Jobs
# 38                     Film Jobs
# 39                  Teacher Jobs
# 40                  Airline Jobs
# 41         Graphic Designer Jobs
# 42                 Shipping Jobs
# 43                Analytics Jobs
# 44    Business Intelligence Jobs
#
#                                                  link
# 0   https://www.naukri.com/accounting-jobs?xt=cats...
# 1   https://www.naukri.com/interior-design-jobs?xt...
# 2   https://www.naukri.com/bank-jobs?xt=catsrch&qf...
# 3   https://www.naukri.com/content-writing-jobs?xt...
# 4   https://www.naukri.com/consultant-jobs?xt=cats...
# 5   https://www.naukri.com/engineering-jobs?xt=cat...
# 6   https://www.naukri.com/export-import-jobs?xt=c...
# 7   https://www.naukri.com/merchandiser-jobs?xt=ca...
# 8   https://www.naukri.com/security-jobs?xt=catsrc...
# 9   https://www.naukri.com/hr-jobs?xt=catsrch&qf[]=12
# 10  https://www.naukri.com/hotel-jobs?xt=catsrch&q...
# 11  https://www.naukri.com/application-programming...
# 12  https://www.naukri.com/client-server-jobs?xt=c...
# 13  https://www.naukri.com/dba-jobs?xt=catsrch&qf[...
# 14  https://www.naukri.com/ecommerce-jobs?xt=catsr...
# 15  https://www.naukri.com/erp-jobs?xt=catsrch&qf[...
# 16  https://www.naukri.com/vlsi-jobs?xt=catsrch&qf...
# 17  https://www.naukri.com/mainframe-jobs?xt=catsr...
# 18  https://www.naukri.com/middleware-jobs?xt=cats...
# 19  https://www.naukri.com/mobile-jobs?xt=catsrch&...
# 20  https://www.naukri.com/network-administrator-j...
# 21  https://www.naukri.com/information-technology-...
# 22  https://www.naukri.com/testing-jobs?xt=catsrch...
# 23  https://www.naukri.com/system-programming-jobs...
# 24  https://www.naukri.com/edp-jobs?xt=catsrch&qf[...
# 25  https://www.naukri.com/telecom-software-jobs?x...
# 26  https://www.naukri.com/telecom-jobs?xt=catsrch...
# 27  https://www.naukri.com/bpo-jobs?xt=catsrch&qf[]=8
# 28  https://www.naukri.com/legal-jobs?xt=catsrch&q...
# 29  https://www.naukri.com/marketing-jobs?xt=catsr...
# 30  https://www.naukri.com/packaging-jobs?xt=catsr...
# 31  https://www.naukri.com/pharma-jobs?xt=catsrch&...
# 32  https://www.naukri.com/maintenance-jobs?xt=cat...
# 33  https://www.naukri.com/logistics-jobs?xt=catsr...
# 34  https://www.naukri.com/sales-jobs?xt=catsrch&q...
# 35  https://www.naukri.com/secretary-jobs?xt=catsr...
# 36  https://www.naukri.com/corporate-planning-jobs...
# 37  https://www.naukri.com/site-engineering-jobs?x...
# 38  https://www.naukri.com/film-jobs?xt=catsrch&qf...
# 39  https://www.naukri.com/teaching-jobs?xt=catsrc...
# 40  https://www.naukri.com/airline-jobs?xt=catsrch...
# 41  https://www.naukri.com/graphic-designer-jobs?x...
# 42  https://www.naukri.com/shipping-jobs?xt=catsrc...
# 43  https://www.naukri.com/analytics-jobs?xt=catsr...
# 44  https://www.naukri.com/business-intelligence-j...

# %%
joblink['link'][0]
# Out:
# 'https://www.naukri.com/accounting-jobs?xt=catsrch&qf[]=1'

# %%
joblink['link'][10]
# Out:
# 'https://www.naukri.com/hotel-jobs?xt=catsrch&qf[]=4'

# %%
joblink['link'][26]
# Out:
# 'https://www.naukri.com/telecom-jobs?xt=catsrch&qf[]=37'

# %% [markdown]
# # The **URL STRUCTURE**
#
# In order to scrape data from one page to the other, the urls need to be created in such a way that it will automatically adjust to move move from one page to the other.
#
# When we look closely at the **urls**, we can see that all the urls have the domain **https://www.naukri.com/** followed by the job type, then the **page number** and a question mark as shown below. We will need to find a way to make the page number generic in order to be able to navigate through different pages automatically.

# %% [markdown]
# Let's first convert our urls to a list

# %%
urls = joblink['link'].tolist()

# %%
urls
# Out:
# ['https://www.naukri.com/accounting-jobs?xt=catsrch&qf[]=1',
#  'https://www.naukri.com/interior-design-jobs?xt=catsrch&qf[]=2',
#  'https://www.naukri.com/bank-jobs?xt=catsrch&qf[]=6',
#  'https://www.naukri.com/content-writing-jobs?xt=catsrch&qf[]=5',
#  'https://www.naukri.com/consultant-jobs?xt=catsrch&qf[]=9',
#  'https://www.naukri.com/engineering-jobs?xt=catsrch&qf[]=21',
#  'https://www.naukri.com/export-import-jobs?xt=catsrch&qf[]=10',
#  'https://www.naukri.com/merchandiser-jobs?xt=catsrch&qf[]=10',
#  'https://www.naukri.com/security-jobs?xt=catsrch&qf[]=45',
#  'https://www.naukri.com/hr-jobs?xt=catsrch&qf[]=12',
#  'https://www.naukri.com/hotel-jobs?xt=catsrch&qf[]=4',
#  'https://www.naukri.com/application-programming-jobs?xt=catsrch&qf[]=24.01',
#  'https://www.naukri.com/client-server-jobs?xt=catsrch&qf[]=24.02',
#  'https://www.naukri.com/dba-jobs?xt=catsrch&qf[]=24.03',
#  'https://www.naukri.com/ecommerce-jobs?xt=catsrch&qf[]=24.12',
#  'https://www.naukri.com/erp-jobs?xt=catsrch&qf[]=24.04',
#  'https://www.naukri.com/vlsi-jobs?xt=catsrch&qf[]=24.05',
#  'https://www.naukri.com/mainframe-jobs?xt=catsrch&qf[]=24.13',
#  'https://www.naukri.com/middleware-jobs?xt=catsrch&qf[]=24.15',
#  'https://www.naukri.com/mobile-jobs?xt=catsrch&qf[]=24.14',
#  'https://www.naukri.com/network-administrator-jobs?xt=catsrch&qf[]=24.06',
#  'https://www.naukri.com/information-technology-jobs?xt=catsrch&qf[]=24',
#  'https://www.naukri.com/testing-jobs?xt=catsrch&qf[]=24.08',
#  'https://www.naukri.com/system-programming-jobs?xt=catsrch&qf[]=24.09',
#  'https://www.naukri.com/edp-jobs?xt=catsrch&qf[]=24.11',
#  'https://www.naukri.com/telecom-software-jobs?xt=catsrch&qf[]=24.10',
#  'https://www.naukri.com/telecom-jobs?xt=catsrch&qf[]=37',
#  'https://www.naukri.com/bpo-jobs?xt=catsrch&qf[]=8',
#  'https://www.naukri.com/legal-jobs?xt=catsrch&qf[]=13',
#  'https://www.naukri.com/marketing-jobs?xt=catsrch&qf[]=15',
#  'https://www.naukri.com/packaging-jobs?xt=catsrch&qf[]=18',
#  'https://www.naukri.com/pharma-jobs?xt=catsrch&qf[]=16',
#  'https://www.naukri.com/maintenance-jobs?xt=catsrch&qf[]=19',
#  'https://www.naukri.com/logistics-jobs?xt=catsrch&qf[]=14',
#  'https://www.naukri.com/sales-jobs?xt=catsrch&qf[]=22',
#  'https://www.naukri.com/secretary-jobs?xt=catsrch&qf[]=11',
#  'https://www.naukri.com/corporate-planning-jobs?xt=catsrch&qf[]=7',
#  'https://www.naukri.com/site-engineering-jobs?xt=catsrch&qf[]=20',
#  'https://www.naukri.com/film-jobs?xt=catsrch&qf[]=43',
#  'https://www.naukri.com/teaching-jobs?xt=catsrch&qf[]=36',
#  'https://www.naukri.com/airline-jobs?xt=catsrch&qf[]=44',
#  'https://www.naukri.com/graphic-designer-jobs?xt=catsrch&qf[]=3',
#  'https://www.naukri.com/shipping-jobs?xt=catsrch&qf[]=82',
#  'https://www.naukri.com/analytics-jobs?xt=catsrch&qf[]=81',
#  'https://www.naukri.com/business-intelligence-jobs?xt=catsrch&qf[]=81']

# %% [markdown]
# <br>
#
# In order to make the **urls** generic. We will need use a library called **Yarl**(Yet another URL library). All url parts: scheme, user, password, host, port, path, query and fragment are accessible by yarl properties.
#
# We will use **yarl** to access different parts of the variuos **urls**.

# %%
joblink['link'][0]
# Out:
# 'https://www.naukri.com/accounting-jobs?xt=catsrch&qf[]=1'

# %% [markdown]
# ### **Given the above URL, the urls parts are as follows:**
#
# scheme == 'https' <br>
# host == 'www.naukri.com' <br>
# port == 443 <br>
# path == '/accounting-jobs' <br>
# query_string == 'xt=catsrch&qf[]=1'

# %%
# #in order to use yarl, we need to first install the yarl library
# !pip install yarl

# %%
#importing the yarl library

import yarl
from yarl import URL

# %%
n = [] #an empty set that will contain the job type of the url
for i in urls:
    n.append(URL(i).path) #getting the job type part of the url using yarl property: path

# %%
#let's see what is contain in 'n'

n
# Out:
# ['/accounting-jobs',
#  '/interior-design-jobs',
#  '/bank-jobs',
#  '/content-writing-jobs',
#  '/consultant-jobs',
#  '/engineering-jobs',
#  '/export-import-jobs',
#  '/merchandiser-jobs',
#  '/security-jobs',
#  '/hr-jobs',
#  '/hotel-jobs',
#  '/application-programming-jobs',
#  '/client-server-jobs',
#  '/dba-jobs',
#  '/ecommerce-jobs',
#  '/erp-jobs',
#  '/vlsi-jobs',
#  '/mainframe-jobs',
#  '/middleware-jobs',
#  '/mobile-jobs',
#  '/network-administrator-jobs',
#  '/information-technology-jobs',
#  '/testing-jobs',
#  '/system-programming-jobs',
#  '/edp-jobs',
#  '/telecom-software-jobs',
#  '/telecom-jobs',
#  '/bpo-jobs',
#  '/legal-jobs',
#  '/marketing-jobs',
#  '/packaging-jobs',
#  '/pharma-jobs',
#  '/maintenance-jobs',
#  '/logistics-jobs',
#  '/sales-jobs',
#  '/secretary-jobs',
#  '/corporate-planning-jobs',
#  '/site-engineering-jobs',
#  '/film-jobs',
#  '/teaching-jobs',
#  '/airline-jobs',
#  '/graphic-designer-jobs',
#  '/shipping-jobs',
#  '/analytics-jobs',
#  '/business-intelligence-jobs']

# %%
m = []

for i in urls:
    m.append(URL(i).query_string)

# %%
m
# Out:
# ['xt=catsrch&qf[]=1',
#  'xt=catsrch&qf[]=2',
#  'xt=catsrch&qf[]=6',
#  'xt=catsrch&qf[]=5',
#  'xt=catsrch&qf[]=9',
#  'xt=catsrch&qf[]=21',
#  'xt=catsrch&qf[]=10',
#  'xt=catsrch&qf[]=10',
#  'xt=catsrch&qf[]=45',
#  'xt=catsrch&qf[]=12',
#  'xt=catsrch&qf[]=4',
#  'xt=catsrch&qf[]=24.01',
#  'xt=catsrch&qf[]=24.02',
#  'xt=catsrch&qf[]=24.03',
#  'xt=catsrch&qf[]=24.12',
#  'xt=catsrch&qf[]=24.04',
#  'xt=catsrch&qf[]=24.05',
#  'xt=catsrch&qf[]=24.13',
#  'xt=catsrch&qf[]=24.15',
#  'xt=catsrch&qf[]=24.14',
#  'xt=catsrch&qf[]=24.06',
#  'xt=catsrch&qf[]=24',
#  'xt=catsrch&qf[]=24.08',
#  'xt=catsrch&qf[]=24.09',
#  'xt=catsrch&qf[]=24.11',
#  'xt=catsrch&qf[]=24.10',
#  'xt=catsrch&qf[]=37',
#  'xt=catsrch&qf[]=8',
#  'xt=catsrch&qf[]=13',
#  'xt=catsrch&qf[]=15',
#  'xt=catsrch&qf[]=18',
#  'xt=catsrch&qf[]=16',
#  'xt=catsrch&qf[]=19',
#  'xt=catsrch&qf[]=14',
#  'xt=catsrch&qf[]=22',
#  'xt=catsrch&qf[]=11',
#  'xt=catsrch&qf[]=7',
#  'xt=catsrch&qf[]=20',
#  'xt=catsrch&qf[]=43',
#  'xt=catsrch&qf[]=36',
#  'xt=catsrch&qf[]=44',
#  'xt=catsrch&qf[]=3',
#  'xt=catsrch&qf[]=82',
#  'xt=catsrch&qf[]=81',
#  'xt=catsrch&qf[]=81']

# %% [markdown]
# <br>
#
# Now that we have been able to extract the variuos parts of the **urls**, we will stitch them together but this time we will add a placeholder **-{}** after the ***job type part*** of the url.

# %%
gen_urls = []

for i in range(len(n)):
    url = 'https://www.naukri.com/' + n[i] + '-{}?' + m[i]
    gen_urls.append(url)

# %% [markdown]
# As seen below, all good. we have the our urls with a placeholder **{}** where we can simply be adding our page numbers to navigate to different pages as we scrape our data.

# %%
gen_urls
# Out:
# ['https://www.naukri.com//accounting-jobs-{}?xt=catsrch&qf[]=1',
#  'https://www.naukri.com//interior-design-jobs-{}?xt=catsrch&qf[]=2',
#  'https://www.naukri.com//bank-jobs-{}?xt=catsrch&qf[]=6',
#  'https://www.naukri.com//content-writing-jobs-{}?xt=catsrch&qf[]=5',
#  'https://www.naukri.com//consultant-jobs-{}?xt=catsrch&qf[]=9',
#  'https://www.naukri.com//engineering-jobs-{}?xt=catsrch&qf[]=21',
#  'https://www.naukri.com//export-import-jobs-{}?xt=catsrch&qf[]=10',
#  'https://www.naukri.com//merchandiser-jobs-{}?xt=catsrch&qf[]=10',
#  'https://www.naukri.com//security-jobs-{}?xt=catsrch&qf[]=45',
#  'https://www.naukri.com//hr-jobs-{}?xt=catsrch&qf[]=12',
#  'https://www.naukri.com//hotel-jobs-{}?xt=catsrch&qf[]=4',
#  'https://www.naukri.com//application-programming-jobs-{}?xt=catsrch&qf[]=24.01',
#  'https://www.naukri.com//client-server-jobs-{}?xt=catsrch&qf[]=24.02',
#  'https://www.naukri.com//dba-jobs-{}?xt=catsrch&qf[]=24.03',
#  'https://www.naukri.com//ecommerce-jobs-{}?xt=catsrch&qf[]=24.12',
#  'https://www.naukri.com//erp-jobs-{}?xt=catsrch&qf[]=24.04',
#  'https://www.naukri.com//vlsi-jobs-{}?xt=catsrch&qf[]=24.05',
#  'https://www.naukri.com//mainframe-jobs-{}?xt=catsrch&qf[]=24.13',
#  'https://www.naukri.com//middleware-jobs-{}?xt=catsrch&qf[]=24.15',
#  'https://www.naukri.com//mobile-jobs-{}?xt=catsrch&qf[]=24.14',
#  'https://www.naukri.com//network-administrator-jobs-{}?xt=catsrch&qf[]=24.06',
#  'https://www.naukri.com//information-technology-jobs-{}?xt=catsrch&qf[]=24',
#  'https://www.naukri.com//testing-jobs-{}?xt=catsrch&qf[]=24.08',
#  'https://www.naukri.com//system-programming-jobs-{}?xt=catsrch&qf[]=24.09',
#  'https://www.naukri.com//edp-jobs-{}?xt=catsrch&qf[]=24.11',
#  'https://www.naukri.com//telecom-software-jobs-{}?xt=catsrch&qf[]=24.10',
#  'https://www.naukri.com//telecom-jobs-{}?xt=catsrch&qf[]=37',
#  'https://www.naukri.com//bpo-jobs-{}?xt=catsrch&qf[]=8',
#  'https://www.naukri.com//legal-jobs-{}?xt=catsrch&qf[]=13',
#  'https://www.naukri.com//marketing-jobs-{}?xt=catsrch&qf[]=15',
#  'https://www.naukri.com//packaging-jobs-{}?xt=catsrch&qf[]=18',
#  'https://www.naukri.com//pharma-jobs-{}?xt=catsrch&qf[]=16',
#  'https://www.naukri.com//maintenance-jobs-{}?xt=catsrch&qf[]=19',
#  'https://www.naukri.com//logistics-jobs-{}?xt=catsrch&qf[]=14',
#  'https://www.naukri.com//sales-jobs-{}?xt=catsrch&qf[]=22',
#  'https://www.naukri.com//secretary-jobs-{}?xt=catsrch&qf[]=11',
#  'https://www.naukri.com//corporate-planning-jobs-{}?xt=catsrch&qf[]=7',
#  'https://www.naukri.com//site-engineering-jobs-{}?xt=catsrch&qf[]=20',
#  'https://www.naukri.com//film-jobs-{}?xt=catsrch&qf[]=43',
#  'https://www.naukri.com//teaching-jobs-{}?xt=catsrch&qf[]=36',
#  'https://www.naukri.com//airline-jobs-{}?xt=catsrch&qf[]=44',
#  'https://www.naukri.com//graphic-designer-jobs-{}?xt=catsrch&qf[]=3',
#  'https://www.naukri.com//shipping-jobs-{}?xt=catsrch&qf[]=82',
#  'https://www.naukri.com//analytics-jobs-{}?xt=catsrch&qf[]=81',
#  'https://www.naukri.com//business-intelligence-jobs-{}?xt=catsrch&qf[]=81']

# %%
joblink.shape
# Out:
# (45, 2)

# %%
len(gen_urls)
# Out:
# 45

# %% [markdown]
# # **Scraping Data From Naukri.Com**

# %% [markdown]
# In order to scrape the required data from naukri.com, we will follow a simple two step process:
#
#
#
# 1.   Define a dataframe which will contain our data
# 2.   Create a generic python code which will help to extract the data as required.

# %% [markdown]
# <br>
#
#
# **Creating a dataframe to store our scraped data**

# %%
df = pd.DataFrame(columns=['Job_title', 'Experience', 'Company', 'Scraping_Date', 'Salary', 'Location', 'Tags_Associated', 'Posting_Date'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [Job_title, Experience, Company, Scraping_Date, Salary, Location, Tags_Associated, Posting_Date]
# Index: []

# %% [markdown]
# **Create a generic python code to scrape the required data**

# %%
for page in range(1,2):
    for urll in gen_urls[0:4]:
        url = urll.format(page)
        driver = webdriver.Chrome()
        driver.get(url)

        time.sleep(5)

        soup = BeautifulSoup(driver.page_source,'html.parser')

        #driver.close()




#         print(soup.prettify())
        #results = soup.find(class_='list')
        job_elems = soup.find_all('article',class_='jobTuple')


        for job_elem in job_elems:

            #job title
            Job_Title = job_elem.find('a',class_='title ellipsis')
            print(Job_Title.text)

#                     #function area
#             func_results = soup.find('p',class_='jdRightItemValue')
#             if func_results is None:
#                 func_results = 'Not Available'
#                 continue
#             else:
#                 func_area = func_results.text
#                 print(func_area)



            # Experience
            #Exp = job_elem.find('li',class_='fleft br2 placeHolderLi experience')
            Exp_span = job_elem.find('span',class_='ellipsis fleft expwdth')
            if Exp_span is None:
                continue
            else:
                Experience = Exp_span.text
                print(Experience)



            # Company
            Company = job_elem.find('a',class_='subTitle ellipsis fleft')
            print(Company.text)


            # Date Scraped
            from datetime import date
            today = date.today()
                    # dd/mm/YY
            date_today = today.strftime("%d/%m/%Y")
            print(date_today)


            # Salary
            Sal = job_elem.find('li',class_='fleft br2 placeHolderLi salary')
            Sal_span = Sal.find('span',class_='ellipsis fleft')
            if Sal_span is None:
                continue
            else:
                Salary = Sal_span.text
                print(Salary)


            # Location for the job post
            #Loc = job_elem.find('li',class_='fleft placeHolder-icons naukicon-srp-location')
            Loc_exp = job_elem.find('span',class_='ellipsis fleft locWdth')
            if Loc_exp is None:
                continue
            else:
                Location = Loc_exp.text
                print(Location)



            #tags

            tags = job_elem.find('li',class_='fleft dot')

            if tags is None:
                continue
            else:
                assoc_tags = tags.text
                print(assoc_tags)


            # Date job Posted
            #date = job_elem.find("div",["fleft"])
            date_posted = job_elem.find('span',class_='fleft postedDate')
            if date_posted is None:
                continue
            else:
                Posting_Date = date_posted.text
                print(Posting_Date)

            df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# Out:
# Senior Executive - Financial Accounting
# 0-2 Yrs
# Bayer
# 29/06/2023
# Not disclosed
# Thane
# Reporting
# 2 Days Ago
# Senior Accounts Executive ( US CPA )
# 0-5 Yrs
# Highrise Solutions
# 29/06/2023
# Not disclosed
# Pune
# Information technology
# 1 Day Ago
# Accounts Executive
# 0-2 Yrs
# Shree Guru Gobind Singh Tricentenary University (SGTU)
# 29/06/2023
# 2.25-2.75 Lacs PA
# Gurgaon/Gurugram
# Tally ERP
# Just Now
# Accounts & Finance Executive
# 0-3 Yrs
# Shahi
# 29/06/2023
# Not disclosed
# Faridabad, Haryana
# Finance And Accounts
# 2 Days Ago
# Finance Associate - Accounts Receivable
# 0-3 Yrs
# Marriott
# 29/06/2023
# Not disclosed
# Kochi/Cochin
# Billing
# 1 Day Ago
# Account Executive
# 0-3 Yrs
# Shri Ramswaroop Digital Technologies Pvt Ltd
# 29/06/2023
# Not disclosed
# Lucknow
# Tally ERP
# 2 Days Ago
# Jr. Accounts Executive
# 0-2 Yrs
# The Ruby Mills Ltd
# 29/06/2023
# Not disclosed
# Mumbai
# Accounting
# Just Now
# Hiring Junior Accounts Executive
# 0-2 Yrs
# OSB India
# 29/06/2023
# Not disclosed
# Bangalore/Bengaluru
# Accounting
# Just Now
# Account Executive
# Sales Account Executive
# 0-3 Yrs
# Crest
# 29/06/2023
# Not disclosed
# Bangalore/Bengaluru
# Sales
# 1 Day Ago
# Accounts Executive
# 0-2 Yrs
# Waves Strategy Advisors
# 29/06/2023
# 1.75-2.75 Lacs PA
# Mumbai Suburban, Maharashtra
# excel
# 1 Day Ago
# Accounts Executive
# 0-3 Yrs
# OVT India Pvt Ltd.
# 29/06/2023
# Not disclosed
# Bhopal, Madhya Pradesh
# Tally
# 2 Days Ago
# Account Executive
# 0-1 Yrs
# Career Launcher Nagpur
# 29/06/2023
# 1-1.5 Lacs PA
# Nagpur, Maharashtra
# Tally ERP
# 2 Days Ago
# US Accounts Executive -Vijayawada - Onsite only
# 0-1 Yrs
# Advansoft International
# 29/06/2023
# 2-2.5 Lacs PA
# Vijayawada, Andhra Pradesh
# Communication Skills
# Today
# Finance & Accounts - Billing Executive (Night shift - Onsite Vadodara)
# 0-3 Yrs
# Ascendion Engineering
# 29/06/2023
# 2.25-2.5 Lacs PA
# Vadodara/ Baroda, Gujarat
# finance and accounts
# 1 Day Ago
# Junior or Senior Accounts  Executive
# 0-5 Yrs
# Synmac Consultants
# 29/06/2023
# 1-5 Lacs PA
# Chennai, Bangalore/Bengaluru, Delhi / NCR
# Statutory Audit
# 3 Days Ago
# General Accounting Ops New Associate-Procure To Pay Processing
# 0-1 Yrs
# Accenture
# 29/06/2023
# Not disclosed
# Bangalore/Bengaluru
# General Accounting Ops
# Few Hours Ago
# Accounts Receivable Executive
# 0-5 Yrs
# Ascendion Engineering
# 29/06/2023
# Not disclosed
# Vadodara/ Baroda, Gujarat
# accounting
# 2 Days Ago
# Accounts Payable Executive
# 0-5 Yrs
# Ascendion Engineering
# 29/06/2023
# 50,000-2 Lacs PA
# Vadodara/ Baroda, Gujarat
# accounting
# 2 Days Ago
# Senior Executive Finance & Accounts
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# Interior Designer and Project Manager
# 0-2 Yrs
# Sai Plastic Industries - Saishkar Interiors
# 29/06/2023
# 1.75-2.75 Lacs PA
# Mumbai Suburban, Maharashtra
# Interior Designing
# Just Now
# Designer Sales / Interior Sales
# 0-5 Yrs
# SOBHA
# 29/06/2023
# Not disclosed
# Bangalore/ Bengaluru, Karnataka
# people skills
# 6 Days Ago
# Interior Design Project Manager
# 0-3 Yrs
# Daveai
# 29/06/2023
# Not disclosed
# Remote
# Documentation
# 4 Days Ago
# Interior Design Project Manager
# 0-3 Yrs
# Daveai
# 29/06/2023
# Not disclosed
# Bangalore/Bengaluru
# Interiors
# 7 Days Ago
# Junior Interior Designer
# 0-4 Yrs
# Chalk Studio
# 29/06/2023
# Not disclosed
# Gurgaon/Gurugram
# CAD
# 4 Days Ago
# Senior Interior Designer
# 2-4 Yrs
# The Dezign Code
# 29/06/2023
# 3.75-6.5 Lacs PA
# Bangalore/ Bengaluru, Karnataka(HSR Layout)
# interior designing
# 2 Days Ago
# Interior Designer
# 0-1 Yrs
# GHD Infra
# 29/06/2023
# Not disclosed
# Panaji/Panjim
# Interiors
# 6 Days Ago
# Interior Designer
# Interior Architect / Designer - Pune & Chhatrapati Sambhaji Nagar (MH)
# 8-13 Yrs
# Endurance Technologies
# 29/06/2023
# 5-15 Lacs PA
# Pune, Maharashtra, Aurangabad, Maharashtra
# Interior Decorator
# 6 Days Ago
# Architect (Interior Designer)
# 1-6 Yrs
# Job Search
# 29/06/2023
# 1-5 Lacs PA
# Mumbai (All Areas)
# interior designing
# Few Hours Ago
# Senior Interior Designer - Expertise (ATS Group)
# 15-20 Yrs
# ATS Greens
# 29/06/2023
# 20-25 Lacs PA
# Noida, Uttar Pradesh
# interior designing
# 1 Day Ago
# Architect & Design Jobs (LED and interior) in Noida
# 1-5 Yrs
# eCentricHR
# 29/06/2023
# 3-4.5 Lacs PA
# Noida, Uttar Pradesh
# interior designing
# 2 Days Ago
# Interior Designer
# 5-9 Yrs
# Hungry Bird It Consulting Services
# 29/06/2023
# Not disclosed
# Hyderabad/ Secunderabad, Telangana, Pune, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)
# Interior designer
# 1 Day Ago
# Senior/Lead Project Manager - Interior Design/Construction
# 6-10 Yrs
# Okda Solutions
# 29/06/2023
# Not disclosed
# Bangalore/Bengaluru
# Design
# 2 Days Ago
# Architect and Interior Designer
# Interior Designer and Project Manager
# 1-5 Yrs
# Ladder And Wings Consulting Ventures
# 29/06/2023
# 2-4.5 Lacs PA
# Greater Noida, Uttar Pradesh
# interior designing
# Just Now
# Interior Designer
# 5-10 Yrs
# Placement Partners
# 29/06/2023
# 7-17 Lacs PA
# Bangalore/ Bengaluru, Karnataka
# interior designing
# 1 Day Ago
# Interior Designer
# 3-8 Yrs
# Belhem Hospitality
# 29/06/2023
# Not disclosed
# Bangalore/Bengaluru
# Interior Design
# Just Now
# Architect / Interior Designer
# 0-1 Yrs
# HNS Architects
# 29/06/2023
# 90,000-1.25 Lacs PA
# Vadodara/ Baroda, Gujarat
# Interior Designing
# 14 Days Ago
# Interior Designer
# 0-3 Yrs
# UIT Studio
# 29/06/2023
# Not disclosed
# Gurgaon/ Gurugram, Haryana
# Sketchup
# 8 Days Ago
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# Branch Relationship Executive - Bank
# 0-4 Yrs
# Randstad
# 29/06/2023
# 2.25-2.75 Lacs PA
# Palghat/ Palakkad, Kerala, Thrissur/ Trichur, Kerala, Calicut/ Kozhikode, Kerala
# client relationship management
# Just Now
# Branch Relationship Executive - Bank
# 0-5 Yrs
# Randstad
# 29/06/2023
# 2.75-3 Lacs PA
# Kochi/ Cochin, Kerala, Kollam/ Quilon, Kerala, Thiruvalla, Kerala
# client relationship management
# 1 Day Ago
# Relationship Officer - Leading Micro finance Bank - Tamil Nadu
# 0-5 Yrs
# Promind Nxt - Leading Recruiter for Micro Finance Banks
# 29/06/2023
# 1.5-2.25 Lacs PA
# Chennai, Tamil Nadu, Coimbatore, Tamil Nadu, Cuddalore, Tamil Nadu
# Banca Sales
# Just Now
# Assistant Relationship Manager | Retail Banking-Fresher
# 0-4 Yrs
# Next Business Services India
# 29/06/2023
# 2.25-4 Lacs PA
# Noida, Haridwar, Kashipur, Ghaziabad, Rudrapur, Haldwani, Gurgaon/Gurugram, Delhi / NCR
# Retail Banking
# 1 Day Ago
# Relationship Branch Manager- Bangalore at Leading Private Bank
# 0-2 Yrs
# Ooliga research Pvt Ltd
# 29/06/2023
# 3-7 Lacs PA
# Bangalore/ Bengaluru, Karnataka
# Field Sales
# 1 Day Ago
# Fresher | Icici Bank | Relationship Manager | PAN India
# 0-0 Yrs
# Tvs Training And Services
# 29/06/2023
# Not disclosed
# Noida, Uttar Pradesh, Ernakulam, Kerala, Kolkata, West Bengal, Hyderabad/Secunderabad, Delhi / NCR, Telangana,
# Banking
# 2 Days Ago
# Icici Bank LTD - Relationship Manager
# 0-2 Yrs
# Tvs Training And Services
# 29/06/2023
# 2.5-2.75 Lacs PA
# Kochi/Cochin, Palghat/ Palakkad, Kerala, Thrissur/ Trichur, Kerala, Calicut/Kozhikode, Trivandrum/ Thiruvananthapuram, Kerala, Kerala Other
# Relationship management
# 1 Day Ago
# Urgent Hiring For investment Banking, Freshers| Pune
# Banking Sector || Sales  Manager || Chennai || Fresher & Experienced
# 0-5 Yrs
# O3 Hire
# 29/06/2023
# 2.5-3 Lacs PA
# Chennai(Vadapalani +1)
# Marketing
# Just Now
# Banking Hiring || Sales  Manager || Chennai | Fresher & Experienced
# 0-5 Yrs
# O3 Hire
# 29/06/2023
# 2.5-3 Lacs PA
# Chennai(Vadapalani +1)
# Marketing
# Just Now
# Relationship Manager- Business Banking Working Capital Mumbai
# 5-10 Yrs
# Hdfc Bank
# 29/06/2023
# Not disclosed
# Mumbai (All Areas)
# Business Banking
# 1 Day Ago
# Hexaware is Hiring For Fresher || Banking operation
# 0-1 Yrs
# Hexaware Technologies
# 29/06/2023
# 50,000-2.25 Lacs PA
# Navi Mumbai, ghansoli
# MBA
# 7 Days Ago
# Hiring For Voice Process Customer Support - Banking
# Banking Operations New Associate-KYC
# 0-1 Yrs
# Accenture
# 29/06/2023
# Not disclosed
# Bangalore/Bengaluru
# AML
# Just Now
# Banking Operations New Associate-KYC
# 0-1 Yrs
# Accenture
# 29/06/2023
# Not disclosed
# Bangalore/Bengaluru
# Anti money laundering
# 1 Day Ago
# Hiring For Banking Voice Process- Egmore
# 0-1 Yrs
# Tech Mahindra
# 29/06/2023
# 1-2.5 Lacs PA
# Chennai
# punjabi
# 2 Days Ago
# Tech Mahindra Hiring For Banking Voice Process
# 0-1 Yrs
# Tech Mahindra
# 29/06/2023
# 1-2.5 Lacs PA
# Chennai, Tamil Nadu
# voice process
# 1 Day Ago
# SMEG-Business Banking-Relationship Manager
# 5-10 Yrs
# ICICI Bank
# 29/06/2023
# Not disclosed
# Bellary/ Ballari, Karnataka, Gangawati, Karnataka, Hubli, Karnataka, Raichur, Karnataka, Davangere, Karnataka, Belagavi/ Belgaum, Karnataka
# working capital
# 1 Day Ago
# SMEG-Business Banking-Relationship Manager
# 8-13 Yrs
# ICICI Bank
# 29/06/2023
# Not disclosed
# Pathanamthitta, Kerala, Kottayam, Kerala, Hyderabad/ Secunderabad, Telangana, Alleppey/ Alappuzha, Kerala, Hazaribag, Jharkhand, Himayathnagar, Telangana, Thrissur/ Trichur, Kerala
# working capital
# 1 Day Ago
# Fresher | Icici Bank | Relationship Manager | PAN India
# 0-0 Yrs
# Tvs Training And Services
# 29/06/2023
# Not disclosed
# Noida, Uttar Pradesh, Ernakulam, Kerala, Kolkata, West Bengal, Ahmedabad, Gurgaon/ Gurugram, Haryana, Delhi / NCR
# Banking
# 10 Days Ago
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# Hiring For freshers-Content writer _Chennai, CBE,HYD, Bangalore & Pune
# 0-0 Yrs
# Cognizant
# 29/06/2023
# Not disclosed
# Hyderabad/ Secunderabad, Telangana, Pune, Maharashtra, Chennai, Tamil Nadu, Coimbatore, Tamil Nadu, Bangalore/ Bengaluru, Karnataka
# freshers
# 1 Day Ago
# Web Content Writer
# 0-5 Yrs
# Target Publications
# 29/06/2023
# Not disclosed
# Mumbai, Mulund
# Content writing
# Few Hours Ago
# SEO Content Writer
# 0-4 Yrs
# Vyrazu Labs
# 29/06/2023
# 1-2 Lacs PA
# Kolkata, West Bengal
# content writing
# 1 Day Ago
# Social Media Content Writer
# 0-1 Yrs
# Global Talent Track
# 29/06/2023
# 1-1.5 Lacs PA
# Pune, Maharashtra(Viman Nagar)
# Content Writing
# 1 Day Ago
# Content Writer
# 0-1 Yrs
# Emblix Solutions
# 29/06/2023
# 1.5-1.75 Lacs PA
# Hyderabad/Secunderabad(Kukatpally)
# Content Writing
# 2 Days Ago
# Telugu Content Writer
# 0-3 Yrs
# HR & Pr Media Broadcasting Entertainment
# 29/06/2023
# Not disclosed
# Hyderabad/Secunderabad(Madhapur)
# Proof Reading
# 7 Days Ago
# Content / Technical Writer
# 0-3 Yrs
# Great Developers
# 29/06/2023
# Not disclosed
# Noida
# Technical
# 1 Day Ago
# Job Opening For Business / Technology Content Writer
# 0-1 Yrs
# Siliconindia
# 29/06/2023
# 5-6 Lacs PA
# Bangalore/Bengaluru(Old Airport Road)
# Journalism
# Today
# Content Writer
# 0-2 Yrs
# Recenturesoft Infotech
# 29/06/2023
# Not disclosed
# Noida, Uttar Pradesh, Ghaziabad, Uttar Pradesh, Gautam Buddha Nagar, Uttar Pradesh
# SEO Writing
# 8 Days Ago
# Social Media Content Writer
# 0-1 Yrs
# Hir Infotech Pvt Ltd
# 29/06/2023
# Not disclosed
# Ahmedabad, Gujarat(Gota)
# Content Creation
# 15 Days Ago
# Content Writer/reporter
# Interns- Content Writer|| Work From Home/ Internship
# 0-1 Yrs
# Webuters
# 29/06/2023
# Not disclosed
# Remote
# content writing
# 9 Days Ago
# Content Writer - Immediate Joining
# 0-3 Yrs
# Flexsin Technologies
# 29/06/2023
# 2-3.75 Lacs PA
# Noida(Sector-63 Noida)
# Proof Reading
# 10 Days Ago
# Content Writer
# 0-3 Yrs
# Solution4professionals
# 29/06/2023
# 2-3.5 Lacs PA
# Hybrid - Ahmedabad
# Creative Writing
# 13 Days Ago
# Content Writer / Blog Writing
# 0-3 Yrs
# Artech
# 29/06/2023
# 50,000-3 Lacs PA
# Hyderabad/Secunderabad
# content writing
# 13 Days Ago
# Content Writer|SAL UPTO 8LPA|Bangalore| Australian Shift
# 0-5 Yrs
# The Job Factory
# 29/06/2023
# 1-5 Lacs PA
# Bangalore/Bengaluru
# Content Writing
# 14 Days Ago
# Content Writer|SAL UPTO 8LPA|Bangalore| Australian Shift
# 0-5 Yrs
# The Job Factory
# 29/06/2023
# 1-5 Lacs PA
# Bangalore/Bengaluru
# Content Writing
# 14 Days Ago
# Content Writer|SAL UPTO 8LPA|Bangalore| Australian Shift
# 0-5 Yrs
# The Job Factory
# 29/06/2023
# 1-5 Lacs PA
# Bangalore/Bengaluru
# Content Writing
# 14 Days Ago
# Content Writer(Mohali)/Intern
# 0-1 Yrs
# BPO Plus
# 29/06/2023
# Not disclosed
# Mohali, Punjab
# writing
# 7 Days Ago
# Journalist/ Content Writer
# 0-5 Yrs
# Minerva Medical Treatment
# 29/06/2023
# Not disclosed
# Delhi / NCR(DaryaGanj)
# content writing
# Few Hours Ago
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_23684\1780558296.py:103: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Job_Title':Job_Title.text,'Experience':Experience,'Company':Company.text,'Scraping_Date':date_today, 'Salary':Salary,'Location':Location,'Tags_Associated':assoc_tags,'Posting_Date':Posting_Date},ignore_index = True)

# %%
df
# Out:
#    Job_title Experience                                            Company  \
# 0        NaN    0-2 Yrs                                              Bayer
# 1        NaN    0-5 Yrs                                 Highrise Solutions
# 2        NaN    0-2 Yrs  Shree Guru Gobind Singh Tricentenary Universit...
# 3        NaN    0-3 Yrs                                              Shahi
# 4        NaN    0-3 Yrs                                           Marriott
# ..       ...        ...                                                ...
# 68       NaN    0-5 Yrs                                    The Job Factory
# 69       NaN    0-5 Yrs                                    The Job Factory
# 70       NaN    0-5 Yrs                                    The Job Factory
# 71       NaN    0-1 Yrs                                           BPO Plus
# 72       NaN    0-5 Yrs                          Minerva Medical Treatment
#
#    Scraping_Date             Salary                Location  \
# 0     29/06/2023      Not disclosed                   Thane
# 1     29/06/2023      Not disclosed                    Pune
# 2     29/06/2023  2.25-2.75 Lacs PA        Gurgaon/Gurugram
# 3     29/06/2023      Not disclosed      Faridabad, Haryana
# 4     29/06/2023      Not disclosed            Kochi/Cochin
# ..           ...                ...                     ...
# 68    29/06/2023        1-5 Lacs PA     Bangalore/Bengaluru
# 69    29/06/2023        1-5 Lacs PA     Bangalore/Bengaluru
# 70    29/06/2023        1-5 Lacs PA     Bangalore/Bengaluru
# 71    29/06/2023      Not disclosed          Mohali, Punjab
# 72    29/06/2023      Not disclosed  Delhi / NCR(DaryaGanj)
#
#            Tags_Associated   Posting_Date  \
# 0                Reporting     2 Days Ago
# 1   Information technology      1 Day Ago
# 2                Tally ERP       Just Now
# 3     Finance And Accounts     2 Days Ago
# 4                  Billing      1 Day Ago
# ..                     ...            ...
# 68         Content Writing    14 Days Ago
# 69         Content Writing    14 Days Ago
# 70         Content Writing    14 Days Ago
# 71                 writing     7 Days Ago
# 72         content writing  Few Hours Ago
#
#                                             Job_Title
# 0             Senior Executive - Financial Accounting
# 1                Senior Accounts Executive ( US CPA )
# 2                                  Accounts Executive
# 3                        Accounts & Finance Executive
# 4             Finance Associate - Accounts Receivable
# ..                                                ...
# 68  Content Writer|SAL UPTO 8LPA|Bangalore| Austra...
# 69  Content Writer|SAL UPTO 8LPA|Bangalore| Austra...
# 70  Content Writer|SAL UPTO 8LPA|Bangalore| Austra...
# 71                      Content Writer(Mohali)/Intern
# 72                         Journalist/ Content Writer
#
# [73 rows x 9 columns]
